# %%
import uproot

file = uproot.open( r"/mnt/d/GoogleDrive/Job/cern/Alice/analysis/data/RhoPrime/2015/245145.AliESDs.root")

events = file["esdTree"];

events.show()
# Out:
# AliESDRun.                 TStreamerInfo              None
# AliESDRun.TObject          (no streamer)              None
# AliESDRun.TObject.fUniqueID
#                            TStreamerBasicType         asdtype('>u4')
# AliESDRun.TObject.fBits    TStreamerBasicType         asdtype('>u4')
#
# AliESDRun.fCurrentL3       TStreamerBasicType         asdtype('>f4')
# AliESDRun.fCurrentDip      TStreamerBasicType         asdtype('>f4')
# AliESDRun.fBeamEnergy      TStreamerBasicType         asdtype('>f4')
# AliESDRun.fMagneticField   TStreamerBasicType         asdtype('>f4', 'float64')
# AliESDRun.fMeanBeamInt[2][2]
#                            TStreamerBasicType         asdtype("('>f4', (2, 2))", "('<f8', (2, 2))")
# AliESDRun.fDiamondXY[2]    TStreamerBasicType         asdtype("('>f4', (2,))", "('<f8', (2,))")
# AliESDRun.fDiamondCovXY[3] TStreamerBasicType         asdtype("('>f4', (3,))", "('<f8', (3,))")
# ...

# %%
a = events.array("Tracks.fFlags")
a
# Out:
# <JaggedArray [[] [] [] ... [] [] []] at 0x7fc0a3be9a90>

# %%
print("events number", events.numentries)
# Out:
# events number 3332

# %%
events.keys("Tracks.fFlags")
# Out:
# [b'AliESDRun.',
#  b'AliESDRun.TObject',
#  b'AliESDRun.TObject.fUniqueID',
#  b'AliESDRun.TObject.fBits',
#  b'AliESDRun.fCurrentL3',
#  b'AliESDRun.fCurrentDip',
#  b'AliESDRun.fBeamEnergy',
#  b'AliESDRun.fMagneticField',
#  b'AliESDRun.fMeanBeamInt[2][2]',
#  b'AliESDRun.fDiamondXY[2]',
#  b'AliESDRun.fDiamondCovXY[3]',
#  b'AliESDRun.fDiamondZ',
#  b'AliESDRun.fDiamondSig2Z',
#  b'AliESDRun.fPeriodNumber',
#  b'AliESDRun.fRunNumber',
#  b'AliESDRun.fRecoVersion',
#  b'AliESDRun.fBeamParticle[2]',
#  b'AliESDRun.fBeamType',
#  b'AliESDRun.fTriggerClasses',
#  b'AliESDRun.fDetInDAQ',
#  b'AliESDRun.fDetInReco',
#  b'AliESDRun.fPHOSMatrix[5]',
#  b'AliESDRun.fEMCALMatrix[22]',
#  b'AliESDRun.fT0spread[4]',
#  b'AliESDRun.fCaloTriggerType[15]',
#  b'AliESDRun.fVZEROEqFactors[64]',
#  b'AliESDRun.fCaloTriggerTypeNew[19]',
#  b'AliESDRun.fCTPStart',
#  b'AliESDRun.fCTPStart.TObject',
#  b'AliESDRun.fCTPStart.fUniqueID',
#  b'AliESDRun.fCTPStart.fBits',
# ...
